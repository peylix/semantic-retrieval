# %%
import pandas as pd

train_df = pd.read_csv("../data/processed/sts_train_clean.csv")
val_df   = pd.read_csv("../data/processed/sts_validation_clean.csv")
test_df  = pd.read_csv("../data/processed/sts_test_clean.csv")

train_df.head()
# Out:
#                                        sentence1  \
# 0                         A plane is taking off.
# 1                A man is playing a large flute.
# 2  A man is spreading shreded cheese on a pizza.
# 3                   Three men are playing chess.
# 4                    A man is playing the cello.
#
#                                            sentence2  score  score_norm
# 0                        An air plane is taking off.   5.00        1.00
# 1                          A man is playing a flute.   3.80        0.76
# 2  A man is spreading shredded cheese on an uncoo...   3.80        0.76
# 3                         Two men are playing chess.   2.60        0.52
# 4                 A man seated is playing the cello.   4.25        0.85
